# %% [markdown]
# ## 감정 분석
# <br>
#
# <b>목차</b>
# (0) [변수 정리](#변수-정리)
# (1) [감성대화말뭉치 tokenized 버전](#(1)-감성대화말뭉치-tokenized-버전)
# (2) [감성대화말뭉치 추가 전처리](#(2)-감성대화말뭉치-추가-전처리)
# (3) [train data의 라벨 분포 확인](#(3)-train-data의-라벨-분포-확인)
# (4) [정수 인코딩](#(4)-정수-인코딩)
# (5) [패딩(padding)](#(5)-패딩(padding))
# (6) [모델링(Modeling)](#(6)-모델링(Modeling))

# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# #### (0) 변수 정리
# - sa: 감성대화말뭉치(ver.토큰) 원본 file
# - ssa: sa[['text_tokenized2', 'bi_sent']] → 감성대화말뭉치에서 토큰, 라벨만 필터링
# - train_data, test_data: 감성대화말뭉치를 3:1 비율로 split
# - df = 추출한 '키워드' 데이터 토큰화한 원본
# - a = '키워드' 데이터의 토큰, type: Series
# - aa = '키워드' 데이터의 토큰, type: 2-dim array
# - ssaa = 감성대화말뭉치 토큰, type: 2-dim array
# - ssa = aa + ssaa, 키워드 토큰 + 감성대화말뭉치 토큰
# - X_train, y_train, X_test, y_test = ssa 데이터프레임 필터
# - ssa_int = ssa 정수 인코딩
# - ssa_int_pad = 패딩 적용

# %% [markdown]
# ------------------------------------------------

# %% [markdown]
# #### (1) 감성대화말뭉치 tokenized 버전
#
# <b>* crawling_data/감성대화말뭉치_ver토큰최종_Training.csv</b>
# - Text: 원문
# - Label: 글의 대표적인 감정 라벨
# - text_tokenized: sentence split, 형태소(n,v,a) 분리
# - text_tokenized2: 불용어 처리

# %%
sa = pd.read_csv('./crawling_data/감성대화말뭉치_ver토큰최종_Training.csv', encoding='utf-8 sig') #미리 토큰화한 감성 문서 활용
del sa['Unnamed: 0']

# %%
sa
# Out:
#                                                     Text Label  \
# 0                              아내가 드디어 출산하게 되어서 정말 신이 나.    기쁨
# 1                당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.    불안
# 2                고등학교에 올라오니 중학교 때보다 수업이 갑자기 어려워져서 당황스러워.    당황
# 3          재취업이 돼서 받게 된 첫 월급으로 온 가족이 외식을 할 예정이야. 너무 행복해.    기쁨
# 4                           빚을 드디어 다 갚게 되어서 이제야 안도감이 들어.    기쁨
# ...                                                  ...   ...
# 40874  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...    불안
# 40875                  지난주에 건강검진 결과가 나왔는데 정상이라고 결과가 나왔어.    기쁨
# 40876          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.    슬픔
# 40877            이렇게 좋은 운동 시설에서 경로 우대로 운동할 수 있다니 참 행운이야.    기쁨
# 40878                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.    불안
#
#                                           text_tokenized  \
# 0       ['아내', '드디어', '출산', '하다', '되어다', '정말', '신', '나']
# 1      ['당뇨', '합병증', '때문', '먹다', '하다', '약', '열', '가지'...
# 2      ['고등학교', '올라오다', '중학교', '때', '수업', '갑자기', '어려워...
# 3      ['재', '취업', '돼다', '받다', '되다', '첫', '월급', '온', ...
# 4      ['빚', '드디어', '다', '갚다', '되어다', '이제야', '안도', '감...
# ...                                                  ...
# 40874  ['같이', '살다', '친구', '애완견', '데려오다', '대부분', '내', ...
# 40875    ['지난주', '건강검진', '결과', '나오다', '정상', '결과', '나오다']
# 40876  ['엄마', '내', '꿈', '작가', '응원', '하다', '주다', '하다',...
# 40877  ['이렇게', '좋다', '운동', '시설', '경로', '우대', '운동', '하...
# 40878  ['친구', '관계', '너무', '힘들다', '베풀다', '만큼', '돌아오다',...
#
#                                          text_tokenized2
# 0                         ['아내', '드디어', '출산', '정말', '신']
# 1      ['당뇨', '합병증', '때문', '먹다', '약', '열', '가지', '넘어가...
# 2      ['고등학교', '올라오다', '중학교', '수업', '갑자기', '어려워지다', ...
# 3      ['취업', '받다', '첫', '월급', '가족', '외식', '예정', '행복하다']
# 4             ['빚', '드디어', '갚다', '이제야', '안도', '감', '들다']
# ...                                                  ...
# 40874  ['살다', '친구', '애완견', '데려오다', '대부분', '돌보다', '주인'...
# 40875    ['지난주', '건강검진', '결과', '나오다', '정상', '결과', '나오다']
# 40876  ['엄마', '꿈', '작가', '응원', '주다', '지금', '그렇다', '슬프다']
# 40877  ['이렇게', '좋다', '운동', '시설', '경로', '우대', '운동', '차...
# 40878           ['친구', '관계', '힘들다', '베풀다', '돌아오다', '않다']
#
# [40879 rows x 4 columns]

# %% [markdown]
# #### (2) 감성대화말뭉치 추가 전처리
# * 감정_대분류:
# 1 = 기쁨
# 0 = 불안, 슬픔, 분노, 상처, 불안
# 당황은 제거
#
#
# <참고> 네이버 쇼핑 리뷰 감성 분류하기 https://wikidocs.net/94600

# %%
sa['Label'].unique()
# Out:
# array(['기쁨', '불안', '당황', '슬픔', '분노', '상처', '불안 ', '기쁨 '], dtype=object)

# %%
sa = sa[sa.Label != '당황']

# %%
sa['bi_sent'] = 0
sa['bi_sent'][(sa['Label'] == '기쁨')] = 1
# Out:
# C:\Users\eunah.lee\AppData\Local\Temp/ipykernel_21364/3765721047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sa['bi_sent'] = 0
# C:\Users\eunah.lee\AppData\Local\Temp/ipykernel_21364/3765721047.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sa['bi_sent'][(sa['Label'] == '기쁨')] = 1
# C:\Users\eunah.lee\Anaconda3\lib\site-packages\pandas\core\generic.py:8870: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
sa[(sa['bi_sent']==1)] # 6,730
sa[(sa['bi_sent']==0)] # 27,789
# Out:
#                                                     Text Label  \
# 1                당뇨랑 합병증 때문에 먹어야 할 약이 열 가지가 넘어가니까 스트레스야.    불안
# 5      이제 곧 은퇴할 시기가 되었어. 내가 먼저 은퇴를 하고 육 개월 후에 남편도 은퇴를...    불안
# 6                          사십 대에 접어들면서 머리카락이 많이 빠져 고민이야.    슬픔
# 7                                         이제 돈이라면 지긋지긋해.    분노
# 8                 친구들이 나를 괴롭혀. 부모님과 선생님께 얘기했는데도 믿어주지 않아.    분노
# ...                                                  ...   ...
# 40872  오늘 식당에서 서빙을 하는데 젊은 청년들이 반말하길래 기분이 나빠 나도 반말을 하며...    분노
# 40873            최 영감이 노인들에게 나를 이상한 사람으로 이야기해서 답답하고 억울해.    상처
# 40874  같이 사는 친구가 애완견을 데려왔는데 대부분 내가 돌보고 있어. 내가 주인인가 혼란...    불안
# 40876          엄마는 내 꿈인 작가를 응원해 주고는 했는데 지금은 안 그래. 너무 슬퍼.    슬픔
# 40878                친구 관계가 너무 힘들어. 베푸는 만큼 돌아오지 않는 것 같아.    불안
#
#                                           text_tokenized  \
# 1      ['당뇨', '합병증', '때문', '먹다', '하다', '약', '열', '가지'...
# 5      ['이제', '곧', '은퇴', '하다', '시기', '되어다', '내', '먼저'...
# 6      ['사다', '대다', '접다', '들다', '머리카락', '많이', '빠지다', ...
# 7                            ['이제', '돈', '라면', '지긋지긋하다']
# 8      ['친구', '나르다', '괴롭히다', '부모님', '선생님', '얘기', '하다'...
# ...                                                  ...
# 40872  ['오늘', '식당', '서빙', '하다', '젊다', '청년', '반말', '하다...
# 40873  ['최', '영감', '노인', '나르다', '이상하다', '사람', '이야기', ...
# 40874  ['같이', '살다', '친구', '애완견', '데려오다', '대부분', '내', ...
# 40876  ['엄마', '내', '꿈', '작가', '응원', '하다', '주다', '하다',...
# 40878  ['친구', '관계', '너무', '힘들다', '베풀다', '만큼', '돌아오다',...
#
#                                          text_tokenized2  bi_sent
# 1      ['당뇨', '합병증', '때문', '먹다', '약', '열', '가지', '넘어가...        0
# 5      ['이제', '은퇴', '시기', '먼저', '은퇴', '개월', '남편', '은퇴...        0
# 6      ['사다', '대다', '접다', '들다', '머리카락', '많이', '빠지다', ...        0
# 7                            ['이제', '돈', '라면', '지긋지긋하다']        0
# 8      ['친구', '나르다', '괴롭히다', '부모님', '선생님', '얘기', '믿다'...        0
# ...                                                  ...      ...
# 40872  ['오늘', '식당', '서빙', '젊다', '청년', '반말', '기분', '나쁘...        0
# 40873  ['최', '영감', '노인', '나르다', '이상하다', '사람', '이야기', ...        0
# 40874  ['살다', '친구', '애완견', '데려오다', '대부분', '돌보다', '주인'...        0
# 40876  ['엄마', '꿈', '작가', '응원', '주다', '지금', '그렇다', '슬프다']        0
# 40878           ['친구', '관계', '힘들다', '베풀다', '돌아오다', '않다']        0
#
# [27789 rows x 5 columns]

# %%
ssa = sa[['text_tokenized2','bi_sent']]
X = ssa['text_tokenized2']
y = ssa['bi_sent']

# %%
# train : test = 3 : 1
train_data, test_data = train_test_split(ssa, test_size = 0.25, shuffle=True,  random_state = 42)

# %%
print('훈련용 리뷰의 개수 :', len(train_data))
print('테스트용 리뷰의 개수 :', len(test_data))
print(train_data.groupby('bi_sent').size().reset_index(name = 'count'))
# Out:
# 훈련용 리뷰의 개수 : 25889
# 테스트용 리뷰의 개수 : 8630
#    bi_sent  count
# 0        0  20853
# 1        1   5036

# %%
train_data
# Out:
#                                          text_tokenized2  bi_sent
# 18419                   ['친구', '승진', '축하', '속이다', '쓰리다']        0
# 11266                   ['동호회', '대회', '일등', '컨디션', '좋다']        1
# 6847                     ['벌써', '은퇴', '걱정', '나이', '슬프다']        0
# 8164                 ['열심히', '공부', '성적', '떨어지다', '낙담하다']        0
# 16021  ['내일', '검진', '결과', '나오다', '나쁘다', '나오다', '보다', ...        0
# ...                                                  ...      ...
# 19948     ['신부전증', '치료', '비다', '믿다', '맡기다', '배신', '당하다']        0
# 7392      ['의사', '생각', '간경변증', '빠르다', '진행', '말', '우울하다']        0
# 13345    ['맡다', '프로젝트', '까다롭다', '팀원', '자다', '해내다', '믿다']        1
# 1026   ['진로', '대해', '자다', '알다', '불구', '성적', '때문', '진학...        0
# 18698  ['모임', '놀다', '늦다', '들어오다', '남편', '캐', '물어', '화가']        0
#
# [25889 rows x 2 columns]

# %% [markdown]
# #### (3) train data의 라벨 분포 확인

# %%
negative_words = np.hstack(train_data[train_data.bi_sent == 0]['text_tokenized2'].values)
positive_words = np.hstack(train_data[train_data.bi_sent == 1]['text_tokenized2'].values)

# %%
from collections import Counter

negative_word_count = Counter(negative_words)
print("부정 리뷰에서 빈도수가 높은 Top 20 단어")
print(negative_word_count.most_common(20))
print()
print("긍정 리뷰에서 빈도수가 높은 Top 20 단어")
positive_word_count = Counter(positive_words)
print(positive_word_count.most_common(20))
# Out:
# 부정 리뷰에서 빈도수가 높은 Top 20 단어
# [("['취업']", 9), ("['슬프다']", 5), ('[]', 5), ("['요즘', '힘들다']", 4), ("['오늘', '기분', '좋다']", 4), ("['요즘', '걱정']", 4), ("['속상하다']", 4), ("['은퇴', '질환', '몸', '아프다']", 4), ("['가족', '생각', '짜증']", 4), ("['실망하다']", 4), ("['요즘', '혼란', '스럽다']", 4), ("['일만', '아니다', '원하다', '대학', '가다']", 3), ("['친구', '따돌림', '당하다', '그냥', '방관', '괴롭다', '죽다']", 3), ("['병원', '다녀오다', '남편', '감시', '속', '살', '진짜', '귀찮다']", 3), ("['요즘', '슬프다']", 3), ("['집', '남편', '옆집', '할머니', '예쁘다', '대놓고', '얘기', '상처', '받다']", 3), ("['힘들다']", 3), ("['남편', '때문', '화가']", 3), ("['어떻다', '이렇다']", 3), ("['일해', '돈', '모이다', '않다']", 3)]
#
# 긍정 리뷰에서 빈도수가 높은 Top 20 단어
# [("['기분', '좋다']", 4), ("['요즘', '행복하다']", 4), ("['업무', '자다', '불평', '직원', '퇴사', '기분', '상쾌하다']", 3), ("['요즘', '기분', '좋다']", 3), ("['오늘', '경찰서', '연락', '받다', '돈', '훔치다', '간', '도둑', '잡다']", 3), ("['젊다', '어서', '건강', '식품', '꾸준하다', '챙기다', '먹다', '건강']", 3), ("['친구', '제주도', '놀다', '가다', '엄마', '흔쾌하다', '허락', '주다', '기쁘다']", 3), ("['집도', '연금', '나오다']", 3), ("['주변', '사람', '신뢰']", 3), ("['재정', '상태', '믿다']", 3), ("['회사', '상사', '퇴근', '퇴근', '회사', '그렇다', '않다', '좋다']", 3), ("['오늘', '첫', '출근']", 3), ("['승진']", 3), ("['결혼', '알다', '딸', '좋다', '사람', '만나다', '결혼', '정말', '안심']", 3), ("['오늘', '옆집', '할멈', '오백만', '건네주다', '오다', '스스로', '자랑스럽다']", 2), ("['양가', '부모님', '결혼', '비용', '많다', '도움', '주다', '든든하다']", 2), ("['회사', '사람', '자다', '맞다', '차다', '감사하다', '일인']", 2), ("['시험', '준비', '시작', '부모님', '정말', '감사', '드리다']", 2), ("['로또', '당첨']", 2), ("['부모님', '당분간', '집', '계시다', '친구', '부르다', '신나다']", 2)]

# %%
fig,(ax1,ax2) = plt.subplots(1,2,figsize=(10,5))
text_len = train_data[train_data['bi_sent']==1]['text_tokenized2'].map(lambda x: len(x))
ax1.hist(text_len, color='red')
ax1.set_title('Positive Reviews')
ax1.set_xlabel('length of samples')
ax1.set_ylabel('number of samples')
print('긍정 리뷰의 평균 길이 :', np.mean(text_len))

text_len = train_data[train_data['bi_sent']==0]['text_tokenized2'].map(lambda x: len(x))
ax2.hist(text_len, color='blue')
ax2.set_title('Negative Reviews')
fig.suptitle('Words in texts')
ax2.set_xlabel('length of samples')
ax2.set_ylabel('number of samples')
print('부정 리뷰의 평균 길이 :', np.mean(text_len))
plt.show()
# Out:
# 긍정 리뷰의 평균 길이 : 42.44956314535346
# 부정 리뷰의 평균 길이 : 43.496427372560305

# %% [markdown]
# * <b>단어 임베딩</b>: 단어의 의미에 대한 무언가를 포착하는 단어의 조밀한 벡터 표현을 제공하는 접근 방식
# * <b>Gensim</b>: 주제 모델링에 중점을 둔 자연어 처리를 위한 라이브러리 (자연어 → 벡터)
# * <b>Word2vec</b>: 텍스트 말뭉치에서 단어 임베딩을 학습하는 하나의 알고리즘

# %%
df = pd.read_csv('./crawling_data/apple_thinq_processing2.csv')
a = df['content_n']

aa = []
for i in range(len(a)):
    aa.append(eval(a[i]))

# %%
import gensim
from gensim.models import Word2Vec, FastText

model = Word2Vec(aa, min_count=1, vector_size=300)

# %%
train_data = train_data.reset_index()
train_data = train_data.drop(columns = ["index"])
train_data
# Out:
#                                          text_tokenized2  bi_sent
# 0                       ['친구', '승진', '축하', '속이다', '쓰리다']        0
# 1                       ['동호회', '대회', '일등', '컨디션', '좋다']        1
# 2                        ['벌써', '은퇴', '걱정', '나이', '슬프다']        0
# 3                    ['열심히', '공부', '성적', '떨어지다', '낙담하다']        0
# 4      ['내일', '검진', '결과', '나오다', '나쁘다', '나오다', '보다', ...        0
# ...                                                  ...      ...
# 25884     ['신부전증', '치료', '비다', '믿다', '맡기다', '배신', '당하다']        0
# 25885     ['의사', '생각', '간경변증', '빠르다', '진행', '말', '우울하다']        0
# 25886    ['맡다', '프로젝트', '까다롭다', '팀원', '자다', '해내다', '믿다']        1
# 25887  ['진로', '대해', '자다', '알다', '불구', '성적', '때문', '진학...        0
# 25888  ['모임', '놀다', '늦다', '들어오다', '남편', '캐', '물어', '화가']        0
#
# [25889 rows x 2 columns]

# %%
a= train_data['text_tokenized2']

# %%
a
# Out:
# 0                         ['친구', '승진', '축하', '속이다', '쓰리다']
# 1                         ['동호회', '대회', '일등', '컨디션', '좋다']
# 2                          ['벌써', '은퇴', '걱정', '나이', '슬프다']
# 3                      ['열심히', '공부', '성적', '떨어지다', '낙담하다']
# 4        ['내일', '검진', '결과', '나오다', '나쁘다', '나오다', '보다', ...
#                                ...
# 25884       ['신부전증', '치료', '비다', '믿다', '맡기다', '배신', '당하다']
# 25885       ['의사', '생각', '간경변증', '빠르다', '진행', '말', '우울하다']
# 25886      ['맡다', '프로젝트', '까다롭다', '팀원', '자다', '해내다', '믿다']
# 25887    ['진로', '대해', '자다', '알다', '불구', '성적', '때문', '진학...
# 25888    ['모임', '놀다', '늦다', '들어오다', '남편', '캐', '물어', '화가']
# Name: text_tokenized2, Length: 25889, dtype: object

# %%
ssaa = []
for i in range(len(a)):
    ssaa.append(eval(a[i]))

# %%
ssa = ssaa + aa

# %%
X_train = train_data['text_tokenized2']  #25,889
y_train = train_data['bi_sent']
X_test = test_data['text_tokenized2'] #8,630
y_test = test_data['bi_sent']

# %% [markdown]
# #### (4) 정수 인코딩
# 기계가 텍스트를 숫자로 처리할 수 있도록 훈련 데이터와 테스트 데이터에 정수 인코딩 수행해야함

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(ssa) # 훈련데이터에 대해 단어 집합 만들기

# %%
threshold = 2
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 9068
# 등장 빈도가 1번 이하인 희귀 단어의 수: 3047
# 단어 집합에서 희귀 단어의 비율: 33.60167622408469
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 1.5451866952680877

# %%
# 등장 빈도가 1번 이하인 희귀 단어는 약 32%를 차지함 → 자연어 처리에서 중요하지 않을 것이므로 제외함
vocab_size = total_cnt - rare_cnt + 2
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 6023

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
tokenizer = Tokenizer(vocab_size, oov_token = 'OOV') 
tokenizer.fit_on_texts(ssa)
ssa_int = tokenizer.texts_to_sequences(ssa)

# %%
len(ssaa) #25,889
# Out:
# 25889

# %%
print(ssa_int[:3])
# Out:
# [[2, 204, 722, 723, 2422], [877, 1006, 822, 1999, 3], [245, 65, 16, 49, 23]]

# %% [markdown]
# #### (5) 패딩(padding)
# 서로 다른 길이의 샘플들의 길이를 동일하게 맞춰줌

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in ssa_int))
print('리뷰의 평균 길이 :',sum(map(len, ssa_int))/len(ssa_int))
plt.hist([len(s) for s in ssa_int], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 206
# 리뷰의 평균 길이 : 7.356026411012049

# %%
def below_threshold_len(max_len, nested_list):
    cnt = 0
    for s in nested_list:
        if(len(s) <= max_len):
            cnt = cnt + 1
    print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 25
below_threshold_len(max_len, ssa_int)
# Out:
# 전체 샘플 중 길이가 25 이하인 샘플의 비율: 98.95922706755698

# %%
# pad.sequences: 행렬 연산을 위해서 여러 문장의 길이를 임의로 동일하게 맞춰주는 작업
ssa_int_pad = pad_sequences(ssa_int, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %% [markdown]
# #### (6) 모델링(Modeling)
# <br>
#
# #### Dense Layer
# : 각 뉴런이 이전 계층의 모든 뉴런으로부터 입력을 받게 됨
# : 즉, 추출된 정보들을 하나의 레이어로 모으고 원하는 차원으로 축소시켜서 표현하기 위한 레이어
# - 첫 번째 인자: 출력 뉴런의 수
# - input_dim: 입력 뉴런의 수
# - activation: 활성화 함수

# %% [markdown]
# #### GRU 모델링
# <b>* Sequential Model:</b>  순차적으로 layer를 더해나가는 방식
# <b>* Embedding Layer:</b> 문자 입력에 대해서 학습을 요할 때 필요한 레이어
# - 첫 번째 인자: 단어 사전의 크기(=학습하고자 하는 단어의 수)
# - 두 번째 인자: output dimension
# - 세 번째 인자: 한 번에 학습하고자 하는 문장의 길이, 다음으로 플래튼 레이어가 오게 되면 반드시 명시해야함
#
# <b>* GRU:</b> LSTM 간소화 버전, LSTM보다 가중치가 적기 때문에 계산량이 적지만 좋은 성능을 냄
# 예) model.add(GRU(hidden_size, input_shape=(timesteps, input_dim)))

# %%
import keras
from keras.layers import Embedding, Dense, GRU, LSTM, SimpleRNN
from keras.models import Sequential
from keras.models import load_model
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
embedding_dim = 64
hidden_units = 256

model = Sequential()
model.add(Embedding(vocab_size, embedding_dim))
model.add(GRU(hidden_units))
model.add(Dense(1, activation='sigmoid'))

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, None, 64)          385472
#
#  gru_1 (GRU)                 (None, 256)               247296
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 633,025
# Trainable params: 633,025
# Non-trainable params: 0
# _________________________________________________________________

# %%
X_train = ssa_int_pad[:len(ssaa)] # 말뭉치만 넣어서 모델 훈련

# %%
len(X_train)
# Out:
# 25889

# %%
# compile(): 모델을 기계가 이해할 수 있도록 컴파일함
# fit(): 모델 학습, 적합
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=es, batch_size=60, validation_split=0.2)

#callbacks=[es, mc],
# Out:
# Epoch 1/15
# 346/346 [==============================] - 18s 47ms/step - loss: 0.2765 - acc: 0.8917 - val_loss: 0.2154 - val_acc: 0.9135
# Epoch 2/15
# 346/346 [==============================] - 15s 43ms/step - loss: 0.1998 - acc: 0.9240 - val_loss: 0.2147 - val_acc: 0.9150
# Epoch 3/15
# 346/346 [==============================] - 15s 43ms/step - loss: 0.1864 - acc: 0.9299 - val_loss: 0.2017 - val_acc: 0.9181
# Epoch 4/15
# 346/346 [==============================] - 15s 43ms/step - loss: 0.1752 - acc: 0.9340 - val_loss: 0.2119 - val_acc: 0.9139
# Epoch 5/15
# 346/346 [==============================] - 15s 44ms/step - loss: 0.1637 - acc: 0.9397 - val_loss: 0.2036 - val_acc: 0.9185
# Epoch 6/15
# 346/346 [==============================] - 15s 43ms/step - loss: 0.1527 - acc: 0.9436 - val_loss: 0.1995 - val_acc: 0.9199
# Epoch 7/15
# 346/346 [==============================] - 15s 43ms/step - loss: 0.1426 - acc: 0.9488 - val_loss: 0.2129 - val_acc: 0.9200
# Epoch 8/15
# 346/346 [==============================] - 15s 43ms/step - loss: 0.1301 - acc: 0.9535 - val_loss: 0.2064 - val_acc: 0.9212
# Epoch 9/15
# 346/346 [==============================] - 15s 42ms/step - loss: 0.1194 - acc: 0.9582 - val_loss: 0.2209 - val_acc: 0.9200
# Epoch 10/15
# 346/346 [==============================] - 15s 43ms/step - loss: 0.1107 - acc: 0.9602 - val_loss: 0.2379 - val_acc: 0.9202
# Epoch 10: early stopping

# %%
#loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (model.evaluate(X_test, y_test)[1]))
# Out:
# 270/270 [==============================] - 3s 12ms/step - loss: 0.9952 - acc: 0.7240
#
#  테스트 정확도: 0.7240

# %%
X_predict = ssa_int_pad[len(ssaa):]
X_predict = X_predict.reshape(918,25,1)

# %%
sent =[]
num=0
for i in range(len(X_predict)):
    print(num,'번째')
    n = 100 - len(aa[i])
    score = np.mean(model.predict(X_predict[i]))
    sent.append(score)
    num=num+1
    if(score > 0.5):
        print("{:.2f}% 확률로 긍정 리뷰입니다.".format(score * 100))
    else:
        print("{:.2f}% 확률로 부정 리뷰입니다.".format((1 - score) * 100))
# Out:
# 0 번째
# 1/1 [==============================] - 0s 430ms/step
# 53.17% 확률로 부정 리뷰입니다.
# 1 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.63% 확률로 긍정 리뷰입니다.
# 2 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.76% 확률로 부정 리뷰입니다.
# 3 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.22% 확률로 부정 리뷰입니다.
# 4 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.97% 확률로 부정 리뷰입니다.
# 5 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 6 번째
# 1/1 [==============================] - 0s 26ms/step
# 55.40% 확률로 부정 리뷰입니다.
# 7 번째
# 1/1 [==============================] - 0s 23ms/step
# 55.18% 확률로 부정 리뷰입니다.
# 8 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.09% 확률로 긍정 리뷰입니다.
# 9 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.68% 확률로 긍정 리뷰입니다.
# 10 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.67% 확률로 부정 리뷰입니다.
# 11 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.24% 확률로 부정 리뷰입니다.
# 12 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.84% 확률로 부정 리뷰입니다.
# 13 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.11% 확률로 부정 리뷰입니다.
# 14 번째
# 1/1 [==============================] - 0s 26ms/step
# 55.01% 확률로 부정 리뷰입니다.
# 15 번째
# 1/1 [==============================] - 0s 30ms/step
# 51.50% 확률로 부정 리뷰입니다.
# 16 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.90% 확률로 부정 리뷰입니다.
# 17 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.35% 확률로 부정 리뷰입니다.
# 18 번째
# 1/1 [==============================] - 0s 24ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 19 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.83% 확률로 부정 리뷰입니다.
# 20 번째
# 1/1 [==============================] - 0s 26ms/step
# 50.12% 확률로 긍정 리뷰입니다.
# 21 번째
# 1/1 [==============================] - 0s 20ms/step
# 56.26% 확률로 부정 리뷰입니다.
# 22 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.42% 확률로 부정 리뷰입니다.
# 23 번째
# 1/1 [==============================] - 0s 22ms/step
# 56.46% 확률로 부정 리뷰입니다.
# 24 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.14% 확률로 부정 리뷰입니다.
# 25 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.91% 확률로 부정 리뷰입니다.
# 26 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.84% 확률로 부정 리뷰입니다.
# 27 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.01% 확률로 부정 리뷰입니다.
# 28 번째
# 1/1 [==============================] - 0s 21ms/step
# 58.21% 확률로 부정 리뷰입니다.
# 29 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.31% 확률로 부정 리뷰입니다.
# 30 번째
# 1/1 [==============================] - 0s 19ms/step
# 60.13% 확률로 부정 리뷰입니다.
# 31 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.89% 확률로 부정 리뷰입니다.
# 32 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.82% 확률로 부정 리뷰입니다.
# 33 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.04% 확률로 부정 리뷰입니다.
# 34 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.41% 확률로 부정 리뷰입니다.
# 35 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.75% 확률로 긍정 리뷰입니다.
# 36 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.28% 확률로 부정 리뷰입니다.
# 37 번째
# 1/1 [==============================] - 0s 23ms/step
# 52.14% 확률로 긍정 리뷰입니다.
# 38 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.54% 확률로 긍정 리뷰입니다.
# 39 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.18% 확률로 부정 리뷰입니다.
# 40 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.14% 확률로 부정 리뷰입니다.
# 41 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.91% 확률로 부정 리뷰입니다.
# 42 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.49% 확률로 긍정 리뷰입니다.
# 43 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.19% 확률로 부정 리뷰입니다.
# 44 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.41% 확률로 긍정 리뷰입니다.
# 45 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.60% 확률로 긍정 리뷰입니다.
# 46 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.82% 확률로 긍정 리뷰입니다.
# 47 번째
# 1/1 [==============================] - 0s 26ms/step
# 50.17% 확률로 긍정 리뷰입니다.
# 48 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.33% 확률로 부정 리뷰입니다.
# 49 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.79% 확률로 부정 리뷰입니다.
# 50 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.27% 확률로 부정 리뷰입니다.
# 51 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.50% 확률로 부정 리뷰입니다.
# 52 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.02% 확률로 긍정 리뷰입니다.
# 53 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.98% 확률로 부정 리뷰입니다.
# 54 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.39% 확률로 긍정 리뷰입니다.
# 55 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.20% 확률로 부정 리뷰입니다.
# 56 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.96% 확률로 부정 리뷰입니다.
# 57 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.15% 확률로 부정 리뷰입니다.
# 58 번째
# 1/1 [==============================] - 0s 19ms/step
# 57.44% 확률로 부정 리뷰입니다.
# 59 번째
# 1/1 [==============================] - 0s 22ms/step
# 52.18% 확률로 부정 리뷰입니다.
# 60 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.28% 확률로 부정 리뷰입니다.
# 61 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.08% 확률로 부정 리뷰입니다.
# 62 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.29% 확률로 부정 리뷰입니다.
# 63 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.02% 확률로 긍정 리뷰입니다.
# 64 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.72% 확률로 부정 리뷰입니다.
# 65 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.50% 확률로 부정 리뷰입니다.
# 66 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.79% 확률로 긍정 리뷰입니다.
# 67 번째
# 1/1 [==============================] - 0s 22ms/step
# 58.76% 확률로 긍정 리뷰입니다.
# 68 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.47% 확률로 부정 리뷰입니다.
# 69 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.52% 확률로 부정 리뷰입니다.
# 70 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.30% 확률로 긍정 리뷰입니다.
# 71 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.16% 확률로 긍정 리뷰입니다.
# 72 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.37% 확률로 부정 리뷰입니다.
# 73 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.39% 확률로 부정 리뷰입니다.
# 74 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.27% 확률로 부정 리뷰입니다.
# 75 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.02% 확률로 긍정 리뷰입니다.
# 76 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.99% 확률로 긍정 리뷰입니다.
# 77 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.09% 확률로 긍정 리뷰입니다.
# 78 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.79% 확률로 부정 리뷰입니다.
# 79 번째
# 1/1 [==============================] - 0s 24ms/step
# 50.10% 확률로 긍정 리뷰입니다.
# 80 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.63% 확률로 부정 리뷰입니다.
# 81 번째
# 1/1 [==============================] - 0s 29ms/step
# 53.66% 확률로 부정 리뷰입니다.
# 82 번째
# 1/1 [==============================] - 0s 22ms/step
# 57.79% 확률로 부정 리뷰입니다.
# 83 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.06% 확률로 부정 리뷰입니다.
# 84 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.22% 확률로 부정 리뷰입니다.
# 85 번째
# 1/1 [==============================] - 0s 24ms/step
# 55.39% 확률로 긍정 리뷰입니다.
# 86 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.73% 확률로 부정 리뷰입니다.
# 87 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.05% 확률로 부정 리뷰입니다.
# 88 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.74% 확률로 부정 리뷰입니다.
# 89 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.53% 확률로 긍정 리뷰입니다.
# 90 번째
# 1/1 [==============================] - 0s 19ms/step
# 57.20% 확률로 부정 리뷰입니다.
# 91 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.31% 확률로 긍정 리뷰입니다.
# 92 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.70% 확률로 부정 리뷰입니다.
# 93 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.34% 확률로 부정 리뷰입니다.
# 94 번째
# 1/1 [==============================] - 0s 18ms/step
# 58.30% 확률로 부정 리뷰입니다.
# 95 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.44% 확률로 부정 리뷰입니다.
# 96 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.73% 확률로 부정 리뷰입니다.
# 97 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.45% 확률로 부정 리뷰입니다.
# 98 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.73% 확률로 부정 리뷰입니다.
# 99 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.56% 확률로 긍정 리뷰입니다.
# 100 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.22% 확률로 부정 리뷰입니다.
# 101 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.23% 확률로 부정 리뷰입니다.
# 102 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.79% 확률로 부정 리뷰입니다.
# 103 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.41% 확률로 부정 리뷰입니다.
# 104 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.49% 확률로 긍정 리뷰입니다.
# 105 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.90% 확률로 긍정 리뷰입니다.
# 106 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.90% 확률로 부정 리뷰입니다.
# 107 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.93% 확률로 부정 리뷰입니다.
# 108 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.96% 확률로 부정 리뷰입니다.
# 109 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.58% 확률로 긍정 리뷰입니다.
# 110 번째
# 1/1 [==============================] - 0s 26ms/step
# 50.87% 확률로 긍정 리뷰입니다.
# 111 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.54% 확률로 부정 리뷰입니다.
# 112 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.97% 확률로 부정 리뷰입니다.
# 113 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.83% 확률로 부정 리뷰입니다.
# 114 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.10% 확률로 부정 리뷰입니다.
# 115 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.12% 확률로 부정 리뷰입니다.
# 116 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.09% 확률로 부정 리뷰입니다.
# 117 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.66% 확률로 부정 리뷰입니다.
# 118 번째
# 1/1 [==============================] - 0s 30ms/step
# 52.77% 확률로 긍정 리뷰입니다.
# 119 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.92% 확률로 부정 리뷰입니다.
# 120 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.26% 확률로 부정 리뷰입니다.
# 121 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.29% 확률로 부정 리뷰입니다.
# 122 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.88% 확률로 긍정 리뷰입니다.
# 123 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.74% 확률로 부정 리뷰입니다.
# 124 번째
# 1/1 [==============================] - 0s 21ms/step
# 56.27% 확률로 부정 리뷰입니다.
# 125 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.76% 확률로 긍정 리뷰입니다.
# 126 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.65% 확률로 긍정 리뷰입니다.
# 127 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.07% 확률로 부정 리뷰입니다.
# 128 번째
# 1/1 [==============================] - 0s 22ms/step
# 54.75% 확률로 부정 리뷰입니다.
# 129 번째
# 1/1 [==============================] - 0s 18ms/step
# 56.97% 확률로 부정 리뷰입니다.
# 130 번째
# 1/1 [==============================] - 0s 23ms/step
# 53.29% 확률로 부정 리뷰입니다.
# 131 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.20% 확률로 부정 리뷰입니다.
# 132 번째
# 1/1 [==============================] - 0s 21ms/step
# 60.98% 확률로 부정 리뷰입니다.
# 133 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.33% 확률로 부정 리뷰입니다.
# 134 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.67% 확률로 부정 리뷰입니다.
# 135 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.28% 확률로 부정 리뷰입니다.
# 136 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.55% 확률로 부정 리뷰입니다.
# 137 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.30% 확률로 부정 리뷰입니다.
# 138 번째
# 1/1 [==============================] - 0s 21ms/step
# 56.44% 확률로 부정 리뷰입니다.
# 139 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.45% 확률로 부정 리뷰입니다.
# 140 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.08% 확률로 부정 리뷰입니다.
# 141 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.67% 확률로 긍정 리뷰입니다.
# 142 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.72% 확률로 긍정 리뷰입니다.
# 143 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.41% 확률로 부정 리뷰입니다.
# 144 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.16% 확률로 부정 리뷰입니다.
# 145 번째
# 1/1 [==============================] - 0s 25ms/step
# 51.76% 확률로 부정 리뷰입니다.
# 146 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.66% 확률로 긍정 리뷰입니다.
# 147 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.39% 확률로 부정 리뷰입니다.
# 148 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.03% 확률로 부정 리뷰입니다.
# 149 번째
# 1/1 [==============================] - 0s 18ms/step
# 63.61% 확률로 부정 리뷰입니다.
# 150 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.09% 확률로 부정 리뷰입니다.
# 151 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.69% 확률로 긍정 리뷰입니다.
# 152 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.66% 확률로 부정 리뷰입니다.
# 153 번째
# 1/1 [==============================] - 0s 17ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 154 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.69% 확률로 긍정 리뷰입니다.
# 155 번째
# 1/1 [==============================] - 0s 18ms/step
# 61.69% 확률로 부정 리뷰입니다.
# 156 번째
# 1/1 [==============================] - 0s 20ms/step
# 56.47% 확률로 부정 리뷰입니다.
# 157 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.49% 확률로 부정 리뷰입니다.
# 158 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.57% 확률로 부정 리뷰입니다.
# 159 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.97% 확률로 부정 리뷰입니다.
# 160 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.92% 확률로 부정 리뷰입니다.
# 161 번째
# 1/1 [==============================] - 0s 22ms/step
# 64.19% 확률로 부정 리뷰입니다.
# 162 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.29% 확률로 부정 리뷰입니다.
# 163 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.77% 확률로 부정 리뷰입니다.
# 164 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.31% 확률로 부정 리뷰입니다.
# 165 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.04% 확률로 부정 리뷰입니다.
# 166 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.44% 확률로 부정 리뷰입니다.
# 167 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.87% 확률로 부정 리뷰입니다.
# 168 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.54% 확률로 부정 리뷰입니다.
# 169 번째
# 1/1 [==============================] - 0s 19ms/step
# 62.70% 확률로 부정 리뷰입니다.
# 170 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.76% 확률로 부정 리뷰입니다.
# 171 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 172 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.65% 확률로 부정 리뷰입니다.
# 173 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.75% 확률로 긍정 리뷰입니다.
# 174 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.64% 확률로 부정 리뷰입니다.
# 175 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.32% 확률로 부정 리뷰입니다.
# 176 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.09% 확률로 부정 리뷰입니다.
# 177 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.64% 확률로 부정 리뷰입니다.
# 178 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.46% 확률로 부정 리뷰입니다.
# 179 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.15% 확률로 부정 리뷰입니다.
# 180 번째
# 1/1 [==============================] - 0s 18ms/step
# 56.01% 확률로 부정 리뷰입니다.
# 181 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.82% 확률로 긍정 리뷰입니다.
# 182 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.80% 확률로 부정 리뷰입니다.
# 183 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.70% 확률로 부정 리뷰입니다.
# 184 번째
# 1/1 [==============================] - 0s 25ms/step
# 52.92% 확률로 부정 리뷰입니다.
# 185 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.82% 확률로 부정 리뷰입니다.
# 186 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.88% 확률로 부정 리뷰입니다.
# 187 번째
# 1/1 [==============================] - 0s 25ms/step
# 54.54% 확률로 부정 리뷰입니다.
# 188 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.45% 확률로 부정 리뷰입니다.
# 189 번째
# 1/1 [==============================] - 0s 28ms/step
# 52.17% 확률로 긍정 리뷰입니다.
# 190 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.32% 확률로 부정 리뷰입니다.
# 191 번째
# 1/1 [==============================] - 0s 17ms/step
# 55.63% 확률로 부정 리뷰입니다.
# 192 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.03% 확률로 긍정 리뷰입니다.
# 193 번째
# 1/1 [==============================] - 0s 24ms/step
# 57.75% 확률로 부정 리뷰입니다.
# 194 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.29% 확률로 부정 리뷰입니다.
# 195 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.28% 확률로 부정 리뷰입니다.
# 196 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.12% 확률로 부정 리뷰입니다.
# 197 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.62% 확률로 부정 리뷰입니다.
# 198 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.70% 확률로 긍정 리뷰입니다.
# 199 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.63% 확률로 부정 리뷰입니다.
# 200 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.26% 확률로 부정 리뷰입니다.
# 201 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.58% 확률로 부정 리뷰입니다.
# 202 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.39% 확률로 긍정 리뷰입니다.
# 203 번째
# 1/1 [==============================] - 0s 23ms/step
# 50.81% 확률로 부정 리뷰입니다.
# 204 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.47% 확률로 부정 리뷰입니다.
# 205 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.72% 확률로 부정 리뷰입니다.
# 206 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.36% 확률로 부정 리뷰입니다.
# 207 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.59% 확률로 부정 리뷰입니다.
# 208 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.83% 확률로 부정 리뷰입니다.
# 209 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.16% 확률로 부정 리뷰입니다.
# 210 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.27% 확률로 부정 리뷰입니다.
# 211 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.01% 확률로 긍정 리뷰입니다.
# 212 번째
# 1/1 [==============================] - 0s 23ms/step
# 50.02% 확률로 긍정 리뷰입니다.
# 213 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.76% 확률로 부정 리뷰입니다.
# 214 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.54% 확률로 긍정 리뷰입니다.
# 215 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.04% 확률로 부정 리뷰입니다.
# 216 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.22% 확률로 부정 리뷰입니다.
# 217 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.33% 확률로 부정 리뷰입니다.
# 218 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.75% 확률로 부정 리뷰입니다.
# 219 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.44% 확률로 부정 리뷰입니다.
# 220 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.88% 확률로 긍정 리뷰입니다.
# 221 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.98% 확률로 부정 리뷰입니다.
# 222 번째
# 1/1 [==============================] - 0s 24ms/step
# 54.63% 확률로 부정 리뷰입니다.
# 223 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.63% 확률로 부정 리뷰입니다.
# 224 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.77% 확률로 부정 리뷰입니다.
# 225 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.24% 확률로 긍정 리뷰입니다.
# 226 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.83% 확률로 부정 리뷰입니다.
# 227 번째
# 1/1 [==============================] - 0s 19ms/step
# 59.08% 확률로 부정 리뷰입니다.
# 228 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.80% 확률로 부정 리뷰입니다.
# 229 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.08% 확률로 부정 리뷰입니다.
# 230 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.87% 확률로 부정 리뷰입니다.
# 231 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.74% 확률로 긍정 리뷰입니다.
# 232 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.26% 확률로 부정 리뷰입니다.
# 233 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.67% 확률로 부정 리뷰입니다.
# 234 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 235 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.33% 확률로 긍정 리뷰입니다.
# 236 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.08% 확률로 부정 리뷰입니다.
# 237 번째
# 1/1 [==============================] - 0s 21ms/step
# 58.23% 확률로 부정 리뷰입니다.
# 238 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.59% 확률로 부정 리뷰입니다.
# 239 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.80% 확률로 부정 리뷰입니다.
# 240 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.87% 확률로 부정 리뷰입니다.
# 241 번째
# 1/1 [==============================] - 0s 21ms/step
# 51.06% 확률로 부정 리뷰입니다.
# 242 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.11% 확률로 부정 리뷰입니다.
# 243 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.49% 확률로 부정 리뷰입니다.
# 244 번째
# 1/1 [==============================] - 0s 22ms/step
# 54.37% 확률로 부정 리뷰입니다.
# 245 번째
# 1/1 [==============================] - 0s 23ms/step
# 50.09% 확률로 부정 리뷰입니다.
# 246 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.16% 확률로 부정 리뷰입니다.
# 247 번째
# 1/1 [==============================] - 0s 27ms/step
# 52.30% 확률로 긍정 리뷰입니다.
# 248 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.81% 확률로 부정 리뷰입니다.
# 249 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.32% 확률로 부정 리뷰입니다.
# 250 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.23% 확률로 부정 리뷰입니다.
# 251 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.73% 확률로 부정 리뷰입니다.
# 252 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.14% 확률로 부정 리뷰입니다.
# 253 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.83% 확률로 긍정 리뷰입니다.
# 254 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.98% 확률로 부정 리뷰입니다.
# 255 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.07% 확률로 부정 리뷰입니다.
# 256 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.06% 확률로 부정 리뷰입니다.
# 257 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.19% 확률로 부정 리뷰입니다.
# 258 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.57% 확률로 부정 리뷰입니다.
# 259 번째
# 1/1 [==============================] - 0s 21ms/step
# 51.99% 확률로 긍정 리뷰입니다.
# 260 번째
# 1/1 [==============================] - 0s 22ms/step
# 54.58% 확률로 부정 리뷰입니다.
# 261 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.26% 확률로 부정 리뷰입니다.
# 262 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.04% 확률로 부정 리뷰입니다.
# 263 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.63% 확률로 부정 리뷰입니다.
# 264 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.34% 확률로 긍정 리뷰입니다.
# 265 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.19% 확률로 부정 리뷰입니다.
# 266 번째
# 1/1 [==============================] - 0s 32ms/step
# 54.69% 확률로 부정 리뷰입니다.
# 267 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.51% 확률로 부정 리뷰입니다.
# 268 번째
# 1/1 [==============================] - 0s 23ms/step
# 61.56% 확률로 긍정 리뷰입니다.
# 269 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.98% 확률로 부정 리뷰입니다.
# 270 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.18% 확률로 긍정 리뷰입니다.
# 271 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.98% 확률로 부정 리뷰입니다.
# 272 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.86% 확률로 부정 리뷰입니다.
# 273 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.72% 확률로 부정 리뷰입니다.
# 274 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.23% 확률로 부정 리뷰입니다.
# 275 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.56% 확률로 부정 리뷰입니다.
# 276 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.63% 확률로 부정 리뷰입니다.
# 277 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.08% 확률로 부정 리뷰입니다.
# 278 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.08% 확률로 긍정 리뷰입니다.
# 279 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.97% 확률로 부정 리뷰입니다.
# 280 번째
# 1/1 [==============================] - 0s 31ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 281 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.51% 확률로 긍정 리뷰입니다.
# 282 번째
# 1/1 [==============================] - 0s 25ms/step
# 51.40% 확률로 부정 리뷰입니다.
# 283 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.95% 확률로 긍정 리뷰입니다.
# 284 번째
# 1/1 [==============================] - 0s 19ms/step
# 57.68% 확률로 부정 리뷰입니다.
# 285 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.42% 확률로 긍정 리뷰입니다.
# 286 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 287 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.93% 확률로 긍정 리뷰입니다.
# 288 번째
# 1/1 [==============================] - 0s 20ms/step
# 58.97% 확률로 부정 리뷰입니다.
# 289 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.25% 확률로 긍정 리뷰입니다.
# 290 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.72% 확률로 부정 리뷰입니다.
# 291 번째
# 1/1 [==============================] - 0s 24ms/step
# 52.09% 확률로 부정 리뷰입니다.
# 292 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.02% 확률로 부정 리뷰입니다.
# 293 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.74% 확률로 부정 리뷰입니다.
# 294 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.54% 확률로 부정 리뷰입니다.
# 295 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.65% 확률로 긍정 리뷰입니다.
# 296 번째
# 1/1 [==============================] - 0s 33ms/step
# 53.15% 확률로 부정 리뷰입니다.
# 297 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.21% 확률로 부정 리뷰입니다.
# 298 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.98% 확률로 긍정 리뷰입니다.
# 299 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.90% 확률로 부정 리뷰입니다.
# 300 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.49% 확률로 부정 리뷰입니다.
# 301 번째
# 1/1 [==============================] - 0s 19ms/step
# 57.16% 확률로 부정 리뷰입니다.
# 302 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.28% 확률로 부정 리뷰입니다.
# 303 번째
# 1/1 [==============================] - 0s 21ms/step
# 56.08% 확률로 부정 리뷰입니다.
# 304 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.52% 확률로 부정 리뷰입니다.
# 305 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.34% 확률로 부정 리뷰입니다.
# 306 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.40% 확률로 긍정 리뷰입니다.
# 307 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.29% 확률로 부정 리뷰입니다.
# 308 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.75% 확률로 부정 리뷰입니다.
# 309 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.84% 확률로 부정 리뷰입니다.
# 310 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.26% 확률로 긍정 리뷰입니다.
# 311 번째
# 1/1 [==============================] - 0s 30ms/step
# 55.07% 확률로 부정 리뷰입니다.
# 312 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.46% 확률로 부정 리뷰입니다.
# 313 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.07% 확률로 긍정 리뷰입니다.
# 314 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.40% 확률로 부정 리뷰입니다.
# 315 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.30% 확률로 부정 리뷰입니다.
# 316 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.96% 확률로 부정 리뷰입니다.
# 317 번째
# 1/1 [==============================] - 0s 20ms/step
# 56.95% 확률로 부정 리뷰입니다.
# 318 번째
# 1/1 [==============================] - 0s 27ms/step
# 54.87% 확률로 부정 리뷰입니다.
# 319 번째
# 1/1 [==============================] - 0s 19ms/step
# 57.55% 확률로 부정 리뷰입니다.
# 320 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.87% 확률로 부정 리뷰입니다.
# 321 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.78% 확률로 부정 리뷰입니다.
# 322 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.18% 확률로 부정 리뷰입니다.
# 323 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.88% 확률로 부정 리뷰입니다.
# 324 번째
# 1/1 [==============================] - 0s 23ms/step
# 53.89% 확률로 부정 리뷰입니다.
# 325 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.14% 확률로 부정 리뷰입니다.
# 326 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.42% 확률로 부정 리뷰입니다.
# 327 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.79% 확률로 부정 리뷰입니다.
# 328 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.08% 확률로 부정 리뷰입니다.
# 329 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.04% 확률로 긍정 리뷰입니다.
# 330 번째
# 1/1 [==============================] - 0s 22ms/step
# 52.63% 확률로 부정 리뷰입니다.
# 331 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.92% 확률로 부정 리뷰입니다.
# 332 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.58% 확률로 부정 리뷰입니다.
# 333 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.04% 확률로 부정 리뷰입니다.
# 334 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.45% 확률로 부정 리뷰입니다.
# 335 번째
# 1/1 [==============================] - 0s 22ms/step
# 54.88% 확률로 부정 리뷰입니다.
# 336 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.32% 확률로 부정 리뷰입니다.
# 337 번째
# 1/1 [==============================] - 0s 21ms/step
# 51.49% 확률로 부정 리뷰입니다.
# 338 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.86% 확률로 부정 리뷰입니다.
# 339 번째
# 1/1 [==============================] - 0s 25ms/step
# 51.09% 확률로 긍정 리뷰입니다.
# 340 번째
# 1/1 [==============================] - 0s 33ms/step
# 54.09% 확률로 부정 리뷰입니다.
# 341 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.98% 확률로 부정 리뷰입니다.
# 342 번째
# 1/1 [==============================] - 0s 21ms/step
# 59.79% 확률로 부정 리뷰입니다.
# 343 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.79% 확률로 부정 리뷰입니다.
# 344 번째
# 1/1 [==============================] - 0s 24ms/step
# 55.63% 확률로 부정 리뷰입니다.
# 345 번째
# 1/1 [==============================] - 0s 22ms/step
# 56.13% 확률로 부정 리뷰입니다.
# 346 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.13% 확률로 긍정 리뷰입니다.
# 347 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.63% 확률로 부정 리뷰입니다.
# 348 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.36% 확률로 부정 리뷰입니다.
# 349 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.45% 확률로 긍정 리뷰입니다.
# 350 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.93% 확률로 부정 리뷰입니다.
# 351 번째
# 1/1 [==============================] - 0s 22ms/step
# 57.73% 확률로 부정 리뷰입니다.
# 352 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.17% 확률로 부정 리뷰입니다.
# 353 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.98% 확률로 부정 리뷰입니다.
# 354 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.91% 확률로 긍정 리뷰입니다.
# 355 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.59% 확률로 부정 리뷰입니다.
# 356 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.80% 확률로 부정 리뷰입니다.
# 357 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.40% 확률로 긍정 리뷰입니다.
# 358 번째
# 1/1 [==============================] - 0s 20ms/step
# 56.31% 확률로 부정 리뷰입니다.
# 359 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.73% 확률로 긍정 리뷰입니다.
# 360 번째
# 1/1 [==============================] - 0s 18ms/step
# 57.01% 확률로 부정 리뷰입니다.
# 361 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.48% 확률로 부정 리뷰입니다.
# 362 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.77% 확률로 부정 리뷰입니다.
# 363 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.53% 확률로 부정 리뷰입니다.
# 364 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.88% 확률로 부정 리뷰입니다.
# 365 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.48% 확률로 부정 리뷰입니다.
# 366 번째
# 1/1 [==============================] - 0s 20ms/step
# 58.56% 확률로 부정 리뷰입니다.
# 367 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.90% 확률로 부정 리뷰입니다.
# 368 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.54% 확률로 부정 리뷰입니다.
# 369 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.72% 확률로 부정 리뷰입니다.
# 370 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.04% 확률로 부정 리뷰입니다.
# 371 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.99% 확률로 부정 리뷰입니다.
# 372 번째
# 1/1 [==============================] - 0s 17ms/step
# 52.58% 확률로 부정 리뷰입니다.
# 373 번째
# 1/1 [==============================] - 0s 29ms/step
# 53.38% 확률로 부정 리뷰입니다.
# 374 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.07% 확률로 부정 리뷰입니다.
# 375 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.26% 확률로 부정 리뷰입니다.
# 376 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.66% 확률로 부정 리뷰입니다.
# 377 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.89% 확률로 부정 리뷰입니다.
# 378 번째
# 1/1 [==============================] - 0s 18ms/step
# 56.48% 확률로 부정 리뷰입니다.
# 379 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.23% 확률로 부정 리뷰입니다.
# 380 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.82% 확률로 부정 리뷰입니다.
# 381 번째
# 1/1 [==============================] - 0s 25ms/step
# 56.16% 확률로 긍정 리뷰입니다.
# 382 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.83% 확률로 긍정 리뷰입니다.
# 383 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.67% 확률로 부정 리뷰입니다.
# 384 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.84% 확률로 부정 리뷰입니다.
# 385 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.62% 확률로 부정 리뷰입니다.
# 386 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.27% 확률로 부정 리뷰입니다.
# 387 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.64% 확률로 부정 리뷰입니다.
# 388 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.16% 확률로 부정 리뷰입니다.
# 389 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.21% 확률로 부정 리뷰입니다.
# 390 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.23% 확률로 긍정 리뷰입니다.
# 391 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.46% 확률로 부정 리뷰입니다.
# 392 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.80% 확률로 부정 리뷰입니다.
# 393 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.67% 확률로 부정 리뷰입니다.
# 394 번째
# 1/1 [==============================] - 0s 23ms/step
# 55.69% 확률로 부정 리뷰입니다.
# 395 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.98% 확률로 부정 리뷰입니다.
# 396 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.63% 확률로 부정 리뷰입니다.
# 397 번째
# 1/1 [==============================] - 0s 23ms/step
# 53.25% 확률로 부정 리뷰입니다.
# 398 번째
# 1/1 [==============================] - 0s 23ms/step
# 52.68% 확률로 부정 리뷰입니다.
# 399 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.13% 확률로 부정 리뷰입니다.
# 400 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.50% 확률로 부정 리뷰입니다.
# 401 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.65% 확률로 긍정 리뷰입니다.
# 402 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.22% 확률로 부정 리뷰입니다.
# 403 번째
# 1/1 [==============================] - 0s 23ms/step
# 55.64% 확률로 부정 리뷰입니다.
# 404 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.82% 확률로 부정 리뷰입니다.
# 405 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.13% 확률로 부정 리뷰입니다.
# 406 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.37% 확률로 긍정 리뷰입니다.
# 407 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.13% 확률로 긍정 리뷰입니다.
# 408 번째
# 1/1 [==============================] - 0s 21ms/step
# 56.01% 확률로 부정 리뷰입니다.
# 409 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.33% 확률로 부정 리뷰입니다.
# 410 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.43% 확률로 부정 리뷰입니다.
# 411 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.18% 확률로 긍정 리뷰입니다.
# 412 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.37% 확률로 부정 리뷰입니다.
# 413 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.09% 확률로 부정 리뷰입니다.
# 414 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.29% 확률로 긍정 리뷰입니다.
# 415 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.40% 확률로 부정 리뷰입니다.
# 416 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.64% 확률로 부정 리뷰입니다.
# 417 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.17% 확률로 부정 리뷰입니다.
# 418 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.68% 확률로 부정 리뷰입니다.
# 419 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.16% 확률로 부정 리뷰입니다.
# 420 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.37% 확률로 긍정 리뷰입니다.
# 421 번째
# 1/1 [==============================] - 0s 29ms/step
# 54.30% 확률로 긍정 리뷰입니다.
# 422 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.97% 확률로 긍정 리뷰입니다.
# 423 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.00% 확률로 부정 리뷰입니다.
# 424 번째
# 1/1 [==============================] - 0s 18ms/step
# 59.02% 확률로 부정 리뷰입니다.
# 425 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.57% 확률로 부정 리뷰입니다.
# 426 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.16% 확률로 부정 리뷰입니다.
# 427 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.15% 확률로 부정 리뷰입니다.
# 428 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.20% 확률로 부정 리뷰입니다.
# 429 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.60% 확률로 부정 리뷰입니다.
# 430 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.67% 확률로 부정 리뷰입니다.
# 431 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.73% 확률로 부정 리뷰입니다.
# 432 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.37% 확률로 부정 리뷰입니다.
# 433 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.47% 확률로 부정 리뷰입니다.
# 434 번째
# 1/1 [==============================] - 0s 21ms/step
# 51.71% 확률로 부정 리뷰입니다.
# 435 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.22% 확률로 부정 리뷰입니다.
# 436 번째
# 1/1 [==============================] - 0s 23ms/step
# 50.36% 확률로 긍정 리뷰입니다.
# 437 번째
# 1/1 [==============================] - 0s 20ms/step
# 58.62% 확률로 부정 리뷰입니다.
# 438 번째
# 1/1 [==============================] - 0s 25ms/step
# 50.48% 확률로 긍정 리뷰입니다.
# 439 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.69% 확률로 부정 리뷰입니다.
# 440 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.40% 확률로 부정 리뷰입니다.
# 441 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.74% 확률로 부정 리뷰입니다.
# 442 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.65% 확률로 부정 리뷰입니다.
# 443 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.72% 확률로 부정 리뷰입니다.
# 444 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.33% 확률로 부정 리뷰입니다.
# 445 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.27% 확률로 긍정 리뷰입니다.
# 446 번째
# 1/1 [==============================] - 0s 25ms/step
# 50.00% 확률로 긍정 리뷰입니다.
# 447 번째
# 1/1 [==============================] - 0s 26ms/step
# 55.82% 확률로 긍정 리뷰입니다.
# 448 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.00% 확률로 부정 리뷰입니다.
# 449 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.47% 확률로 부정 리뷰입니다.
# 450 번째
# 1/1 [==============================] - 0s 20ms/step
# 56.20% 확률로 부정 리뷰입니다.
# 451 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.22% 확률로 부정 리뷰입니다.
# 452 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.64% 확률로 부정 리뷰입니다.
# 453 번째
# 1/1 [==============================] - 0s 24ms/step
# 52.04% 확률로 긍정 리뷰입니다.
# 454 번째
# 1/1 [==============================] - 0s 21ms/step
# 51.17% 확률로 부정 리뷰입니다.
# 455 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.72% 확률로 부정 리뷰입니다.
# 456 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.40% 확률로 긍정 리뷰입니다.
# 457 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.45% 확률로 부정 리뷰입니다.
# 458 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.76% 확률로 긍정 리뷰입니다.
# 459 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.79% 확률로 부정 리뷰입니다.
# 460 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.49% 확률로 부정 리뷰입니다.
# 461 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.73% 확률로 부정 리뷰입니다.
# 462 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.28% 확률로 부정 리뷰입니다.
# 463 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.59% 확률로 부정 리뷰입니다.
# 464 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.57% 확률로 긍정 리뷰입니다.
# 465 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.89% 확률로 부정 리뷰입니다.
# 466 번째
# 1/1 [==============================] - 0s 19ms/step
# 65.39% 확률로 부정 리뷰입니다.
# 467 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.41% 확률로 부정 리뷰입니다.
# 468 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.61% 확률로 부정 리뷰입니다.
# 469 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.48% 확률로 긍정 리뷰입니다.
# 470 번째
# 1/1 [==============================] - 0s 18ms/step
# 56.69% 확률로 부정 리뷰입니다.
# 471 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.35% 확률로 부정 리뷰입니다.
# 472 번째
# 1/1 [==============================] - 0s 24ms/step
# 57.78% 확률로 부정 리뷰입니다.
# 473 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.29% 확률로 부정 리뷰입니다.
# 474 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.84% 확률로 부정 리뷰입니다.
# 475 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.61% 확률로 부정 리뷰입니다.
# 476 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.16% 확률로 부정 리뷰입니다.
# 477 번째
# 1/1 [==============================] - 0s 17ms/step
# 58.14% 확률로 긍정 리뷰입니다.
# 478 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.62% 확률로 부정 리뷰입니다.
# 479 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.28% 확률로 부정 리뷰입니다.
# 480 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.09% 확률로 부정 리뷰입니다.
# 481 번째
# 1/1 [==============================] - 0s 17ms/step
# 52.32% 확률로 부정 리뷰입니다.
# 482 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.13% 확률로 긍정 리뷰입니다.
# 483 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.11% 확률로 부정 리뷰입니다.
# 484 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.02% 확률로 부정 리뷰입니다.
# 485 번째
# 1/1 [==============================] - 0s 18ms/step
# 57.29% 확률로 부정 리뷰입니다.
# 486 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.07% 확률로 부정 리뷰입니다.
# 487 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.25% 확률로 긍정 리뷰입니다.
# 488 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.09% 확률로 부정 리뷰입니다.
# 489 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.27% 확률로 부정 리뷰입니다.
# 490 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.53% 확률로 부정 리뷰입니다.
# 491 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.77% 확률로 부정 리뷰입니다.
# 492 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.97% 확률로 부정 리뷰입니다.
# 493 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.75% 확률로 긍정 리뷰입니다.
# 494 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.32% 확률로 부정 리뷰입니다.
# 495 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.25% 확률로 부정 리뷰입니다.
# 496 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.37% 확률로 부정 리뷰입니다.
# 497 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.57% 확률로 부정 리뷰입니다.
# 498 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.31% 확률로 부정 리뷰입니다.
# 499 번째
# 1/1 [==============================] - 0s 21ms/step
# 56.27% 확률로 부정 리뷰입니다.
# 500 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.03% 확률로 긍정 리뷰입니다.
# 501 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.76% 확률로 긍정 리뷰입니다.
# 502 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.83% 확률로 긍정 리뷰입니다.
# 503 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.26% 확률로 부정 리뷰입니다.
# 504 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.05% 확률로 부정 리뷰입니다.
# 505 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.43% 확률로 부정 리뷰입니다.
# 506 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.28% 확률로 긍정 리뷰입니다.
# 507 번째
# 1/1 [==============================] - 0s 24ms/step
# 51.09% 확률로 부정 리뷰입니다.
# 508 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.93% 확률로 긍정 리뷰입니다.
# 509 번째
# 1/1 [==============================] - 0s 20ms/step
# 58.07% 확률로 부정 리뷰입니다.
# 510 번째
# 1/1 [==============================] - 0s 28ms/step
# 50.64% 확률로 부정 리뷰입니다.
# 511 번째
# 1/1 [==============================] - 0s 22ms/step
# 57.06% 확률로 긍정 리뷰입니다.
# 512 번째
# 1/1 [==============================] - 0s 17ms/step
# 52.63% 확률로 긍정 리뷰입니다.
# 513 번째
# 1/1 [==============================] - 0s 21ms/step
# 58.14% 확률로 부정 리뷰입니다.
# 514 번째
# 1/1 [==============================] - 0s 24ms/step
# 52.24% 확률로 긍정 리뷰입니다.
# 515 번째
# 1/1 [==============================] - 0s 25ms/step
# 52.37% 확률로 부정 리뷰입니다.
# 516 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.94% 확률로 긍정 리뷰입니다.
# 517 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.76% 확률로 부정 리뷰입니다.
# 518 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.31% 확률로 부정 리뷰입니다.
# 519 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.34% 확률로 긍정 리뷰입니다.
# 520 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.20% 확률로 긍정 리뷰입니다.
# 521 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.76% 확률로 부정 리뷰입니다.
# 522 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.95% 확률로 부정 리뷰입니다.
# 523 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.22% 확률로 부정 리뷰입니다.
# 524 번째
# 1/1 [==============================] - 0s 24ms/step
# 50.16% 확률로 부정 리뷰입니다.
# 525 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.02% 확률로 긍정 리뷰입니다.
# 526 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.68% 확률로 부정 리뷰입니다.
# 527 번째
# 1/1 [==============================] - 0s 21ms/step
# 61.89% 확률로 긍정 리뷰입니다.
# 528 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.22% 확률로 부정 리뷰입니다.
# 529 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.18% 확률로 부정 리뷰입니다.
# 530 번째
# 1/1 [==============================] - 0s 18ms/step
# 62.54% 확률로 부정 리뷰입니다.
# 531 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.24% 확률로 긍정 리뷰입니다.
# 532 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.68% 확률로 부정 리뷰입니다.
# 533 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.56% 확률로 부정 리뷰입니다.
# 534 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.42% 확률로 긍정 리뷰입니다.
# 535 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.83% 확률로 긍정 리뷰입니다.
# 536 번째
# 1/1 [==============================] - 0s 19ms/step
# 57.12% 확률로 긍정 리뷰입니다.
# 537 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.94% 확률로 부정 리뷰입니다.
# 538 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.27% 확률로 부정 리뷰입니다.
# 539 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.04% 확률로 긍정 리뷰입니다.
# 540 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.97% 확률로 긍정 리뷰입니다.
# 541 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.01% 확률로 긍정 리뷰입니다.
# 542 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.95% 확률로 긍정 리뷰입니다.
# 543 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.04% 확률로 긍정 리뷰입니다.
# 544 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.25% 확률로 부정 리뷰입니다.
# 545 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.48% 확률로 긍정 리뷰입니다.
# 546 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.72% 확률로 긍정 리뷰입니다.
# 547 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.71% 확률로 긍정 리뷰입니다.
# 548 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.00% 확률로 긍정 리뷰입니다.
# 549 번째
# 1/1 [==============================] - 0s 23ms/step
# 53.18% 확률로 부정 리뷰입니다.
# 550 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.79% 확률로 부정 리뷰입니다.
# 551 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.36% 확률로 긍정 리뷰입니다.
# 552 번째
# 1/1 [==============================] - 0s 24ms/step
# 51.76% 확률로 긍정 리뷰입니다.
# 553 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.62% 확률로 부정 리뷰입니다.
# 554 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.37% 확률로 부정 리뷰입니다.
# 555 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.61% 확률로 부정 리뷰입니다.
# 556 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.13% 확률로 긍정 리뷰입니다.
# 557 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.54% 확률로 부정 리뷰입니다.
# 558 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.46% 확률로 긍정 리뷰입니다.
# 559 번째
# 1/1 [==============================] - 0s 27ms/step
# 51.93% 확률로 긍정 리뷰입니다.
# 560 번째
# 1/1 [==============================] - 0s 27ms/step
# 53.76% 확률로 부정 리뷰입니다.
# 561 번째
# 1/1 [==============================] - 0s 19ms/step
# 59.98% 확률로 부정 리뷰입니다.
# 562 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.22% 확률로 긍정 리뷰입니다.
# 563 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.83% 확률로 긍정 리뷰입니다.
# 564 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.22% 확률로 부정 리뷰입니다.
# 565 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.25% 확률로 부정 리뷰입니다.
# 566 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.34% 확률로 부정 리뷰입니다.
# 567 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.05% 확률로 긍정 리뷰입니다.
# 568 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.59% 확률로 부정 리뷰입니다.
# 569 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.25% 확률로 긍정 리뷰입니다.
# 570 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.78% 확률로 긍정 리뷰입니다.
# 571 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.96% 확률로 긍정 리뷰입니다.
# 572 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.38% 확률로 부정 리뷰입니다.
# 573 번째
# 1/1 [==============================] - 0s 23ms/step
# 50.22% 확률로 긍정 리뷰입니다.
# 574 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.06% 확률로 부정 리뷰입니다.
# 575 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.78% 확률로 부정 리뷰입니다.
# 576 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.75% 확률로 부정 리뷰입니다.
# 577 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.35% 확률로 긍정 리뷰입니다.
# 578 번째
# 1/1 [==============================] - 0s 19ms/step
# 59.34% 확률로 부정 리뷰입니다.
# 579 번째
# 1/1 [==============================] - 0s 30ms/step
# 52.57% 확률로 부정 리뷰입니다.
# 580 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.21% 확률로 긍정 리뷰입니다.
# 581 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.61% 확률로 부정 리뷰입니다.
# 582 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.57% 확률로 부정 리뷰입니다.
# 583 번째
# 1/1 [==============================] - 0s 18ms/step
# 59.64% 확률로 부정 리뷰입니다.
# 584 번째
# 1/1 [==============================] - 0s 23ms/step
# 54.32% 확률로 긍정 리뷰입니다.
# 585 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.82% 확률로 긍정 리뷰입니다.
# 586 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.06% 확률로 긍정 리뷰입니다.
# 587 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.22% 확률로 긍정 리뷰입니다.
# 588 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.76% 확률로 부정 리뷰입니다.
# 589 번째
# 1/1 [==============================] - 0s 22ms/step
# 57.37% 확률로 부정 리뷰입니다.
# 590 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.89% 확률로 긍정 리뷰입니다.
# 591 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.69% 확률로 부정 리뷰입니다.
# 592 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.70% 확률로 부정 리뷰입니다.
# 593 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.13% 확률로 부정 리뷰입니다.
# 594 번째
# 1/1 [==============================] - 0s 19ms/step
# 60.83% 확률로 긍정 리뷰입니다.
# 595 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.17% 확률로 부정 리뷰입니다.
# 596 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.78% 확률로 부정 리뷰입니다.
# 597 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.90% 확률로 부정 리뷰입니다.
# 598 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.76% 확률로 부정 리뷰입니다.
# 599 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.63% 확률로 부정 리뷰입니다.
# 600 번째
# 1/1 [==============================] - 0s 18ms/step
# 62.23% 확률로 부정 리뷰입니다.
# 601 번째
# ...
# 718 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.74% 확률로 긍정 리뷰입니다.
# 719 번째
# 1/1 [==============================] - 0s 20ms/step
# 56.33% 확률로 부정 리뷰입니다.
# 720 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.05% 확률로 긍정 리뷰입니다.
# 721 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.26% 확률로 부정 리뷰입니다.
# 722 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.94% 확률로 긍정 리뷰입니다.
# 723 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.25% 확률로 부정 리뷰입니다.
# 724 번째
# 1/1 [==============================] - 0s 22ms/step
# 52.79% 확률로 긍정 리뷰입니다.
# 725 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.47% 확률로 긍정 리뷰입니다.
# 726 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.80% 확률로 긍정 리뷰입니다.
# 727 번째
# 1/1 [==============================] - 0s 24ms/step
# 50.16% 확률로 부정 리뷰입니다.
# 728 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.64% 확률로 긍정 리뷰입니다.
# 729 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.80% 확률로 긍정 리뷰입니다.
# 730 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.85% 확률로 긍정 리뷰입니다.
# 731 번째
# 1/1 [==============================] - 0s 24ms/step
# 54.07% 확률로 긍정 리뷰입니다.
# 732 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.20% 확률로 긍정 리뷰입니다.
# 733 번째
# 1/1 [==============================] - 0s 18ms/step
# 52.19% 확률로 긍정 리뷰입니다.
# 734 번째
# 1/1 [==============================] - 0s 20ms/step
# 56.09% 확률로 긍정 리뷰입니다.
# 735 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.95% 확률로 부정 리뷰입니다.
# 736 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.11% 확률로 부정 리뷰입니다.
# 737 번째
# 1/1 [==============================] - 0s 22ms/step
# 55.64% 확률로 부정 리뷰입니다.
# 738 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.65% 확률로 부정 리뷰입니다.
# 739 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.06% 확률로 부정 리뷰입니다.
# 740 번째
# 1/1 [==============================] - 0s 20ms/step
# 58.07% 확률로 부정 리뷰입니다.
# 741 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.56% 확률로 부정 리뷰입니다.
# 742 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.06% 확률로 부정 리뷰입니다.
# 743 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.92% 확률로 부정 리뷰입니다.
# 744 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.78% 확률로 긍정 리뷰입니다.
# 745 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.47% 확률로 부정 리뷰입니다.
# 746 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.84% 확률로 부정 리뷰입니다.
# 747 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.98% 확률로 긍정 리뷰입니다.
# 748 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.81% 확률로 부정 리뷰입니다.
# 749 번째
# 1/1 [==============================] - 0s 18ms/step
# 57.43% 확률로 부정 리뷰입니다.
# 750 번째
# 1/1 [==============================] - 0s 25ms/step
# 54.40% 확률로 부정 리뷰입니다.
# 751 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.62% 확률로 긍정 리뷰입니다.
# 752 번째
# 1/1 [==============================] - 0s 23ms/step
# 51.34% 확률로 부정 리뷰입니다.
# 753 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.26% 확률로 부정 리뷰입니다.
# 754 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.74% 확률로 부정 리뷰입니다.
# 755 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.93% 확률로 긍정 리뷰입니다.
# 756 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.59% 확률로 긍정 리뷰입니다.
# 757 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.25% 확률로 부정 리뷰입니다.
# 758 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.51% 확률로 긍정 리뷰입니다.
# 759 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.57% 확률로 긍정 리뷰입니다.
# 760 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.58% 확률로 부정 리뷰입니다.
# 761 번째
# 1/1 [==============================] - 0s 21ms/step
# 55.38% 확률로 부정 리뷰입니다.
# 762 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.37% 확률로 긍정 리뷰입니다.
# 763 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.04% 확률로 긍정 리뷰입니다.
# 764 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.15% 확률로 긍정 리뷰입니다.
# 765 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.18% 확률로 부정 리뷰입니다.
# 766 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.21% 확률로 부정 리뷰입니다.
# 767 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.24% 확률로 긍정 리뷰입니다.
# 768 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.43% 확률로 긍정 리뷰입니다.
# 769 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.79% 확률로 부정 리뷰입니다.
# 770 번째
# 1/1 [==============================] - 0s 23ms/step
# 58.43% 확률로 부정 리뷰입니다.
# 771 번째
# 1/1 [==============================] - 0s 19ms/step
# 54.17% 확률로 부정 리뷰입니다.
# 772 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.33% 확률로 긍정 리뷰입니다.
# 773 번째
# 1/1 [==============================] - 0s 25ms/step
# 50.02% 확률로 긍정 리뷰입니다.
# 774 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.50% 확률로 긍정 리뷰입니다.
# 775 번째
# 1/1 [==============================] - 0s 18ms/step
# 53.26% 확률로 긍정 리뷰입니다.
# 776 번째
# 1/1 [==============================] - 0s 25ms/step
# 51.20% 확률로 긍정 리뷰입니다.
# 777 번째
# 1/1 [==============================] - 0s 19ms/step
# 58.11% 확률로 긍정 리뷰입니다.
# 778 번째
# 1/1 [==============================] - 0s 25ms/step
# 56.10% 확률로 긍정 리뷰입니다.
# 779 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.42% 확률로 부정 리뷰입니다.
# 780 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.83% 확률로 부정 리뷰입니다.
# 781 번째
# 1/1 [==============================] - 0s 23ms/step
# 57.86% 확률로 부정 리뷰입니다.
# 782 번째
# 1/1 [==============================] - 0s 21ms/step
# 51.09% 확률로 긍정 리뷰입니다.
# 783 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.72% 확률로 부정 리뷰입니다.
# 784 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.80% 확률로 부정 리뷰입니다.
# 785 번째
# 1/1 [==============================] - 0s 18ms/step
# 58.39% 확률로 긍정 리뷰입니다.
# 786 번째
# 1/1 [==============================] - 0s 28ms/step
# 52.44% 확률로 부정 리뷰입니다.
# 787 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.24% 확률로 긍정 리뷰입니다.
# 788 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.74% 확률로 부정 리뷰입니다.
# 789 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.70% 확률로 긍정 리뷰입니다.
# 790 번째
# 1/1 [==============================] - 0s 25ms/step
# 53.59% 확률로 부정 리뷰입니다.
# 791 번째
# 1/1 [==============================] - 0s 23ms/step
# 54.49% 확률로 긍정 리뷰입니다.
# 792 번째
# 1/1 [==============================] - 0s 22ms/step
# 53.29% 확률로 긍정 리뷰입니다.
# 793 번째
# 1/1 [==============================] - 0s 26ms/step
# 51.49% 확률로 부정 리뷰입니다.
# 794 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.95% 확률로 부정 리뷰입니다.
# 795 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.91% 확률로 긍정 리뷰입니다.
# 796 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.59% 확률로 부정 리뷰입니다.
# 797 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.76% 확률로 긍정 리뷰입니다.
# 798 번째
# 1/1 [==============================] - 0s 18ms/step
# 57.36% 확률로 긍정 리뷰입니다.
# 799 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.67% 확률로 긍정 리뷰입니다.
# 800 번째
# 1/1 [==============================] - 0s 20ms/step
# 61.48% 확률로 긍정 리뷰입니다.
# 801 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.15% 확률로 부정 리뷰입니다.
# 802 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.17% 확률로 부정 리뷰입니다.
# 803 번째
# 1/1 [==============================] - 0s 20ms/step
# 58.23% 확률로 부정 리뷰입니다.
# 804 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.56% 확률로 긍정 리뷰입니다.
# 805 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.94% 확률로 긍정 리뷰입니다.
# 806 번째
# 1/1 [==============================] - 0s 19ms/step
# 59.48% 확률로 부정 리뷰입니다.
# 807 번째
# 1/1 [==============================] - 0s 24ms/step
# 52.79% 확률로 부정 리뷰입니다.
# 808 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.16% 확률로 부정 리뷰입니다.
# 809 번째
# 1/1 [==============================] - 0s 19ms/step
# 59.75% 확률로 부정 리뷰입니다.
# 810 번째
# 1/1 [==============================] - 0s 27ms/step
# 50.72% 확률로 긍정 리뷰입니다.
# 811 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.41% 확률로 긍정 리뷰입니다.
# 812 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.32% 확률로 부정 리뷰입니다.
# 813 번째
# 1/1 [==============================] - 0s 25ms/step
# 52.69% 확률로 부정 리뷰입니다.
# 814 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.18% 확률로 긍정 리뷰입니다.
# 815 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.49% 확률로 긍정 리뷰입니다.
# 816 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.92% 확률로 부정 리뷰입니다.
# 817 번째
# 1/1 [==============================] - 0s 20ms/step
# 52.26% 확률로 부정 리뷰입니다.
# 818 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.47% 확률로 부정 리뷰입니다.
# 819 번째
# 1/1 [==============================] - 0s 18ms/step
# 57.30% 확률로 긍정 리뷰입니다.
# 820 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.73% 확률로 긍정 리뷰입니다.
# 821 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.01% 확률로 부정 리뷰입니다.
# 822 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.49% 확률로 부정 리뷰입니다.
# 823 번째
# 1/1 [==============================] - 0s 25ms/step
# 51.86% 확률로 부정 리뷰입니다.
# 824 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.50% 확률로 긍정 리뷰입니다.
# 825 번째
# 1/1 [==============================] - 0s 25ms/step
# 51.76% 확률로 긍정 리뷰입니다.
# 826 번째
# 1/1 [==============================] - 0s 23ms/step
# 56.48% 확률로 긍정 리뷰입니다.
# 827 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.63% 확률로 긍정 리뷰입니다.
# 828 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.88% 확률로 긍정 리뷰입니다.
# 829 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.61% 확률로 부정 리뷰입니다.
# 830 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.51% 확률로 긍정 리뷰입니다.
# 831 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.23% 확률로 긍정 리뷰입니다.
# 832 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.39% 확률로 부정 리뷰입니다.
# 833 번째
# 1/1 [==============================] - 0s 23ms/step
# 53.09% 확률로 긍정 리뷰입니다.
# 834 번째
# 1/1 [==============================] - 0s 24ms/step
# 53.11% 확률로 긍정 리뷰입니다.
# 835 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.08% 확률로 부정 리뷰입니다.
# 836 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.04% 확률로 긍정 리뷰입니다.
# 837 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.44% 확률로 부정 리뷰입니다.
# 838 번째
# 1/1 [==============================] - 0s 20ms/step
# 55.85% 확률로 긍정 리뷰입니다.
# 839 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.18% 확률로 긍정 리뷰입니다.
# 840 번째
# 1/1 [==============================] - 0s 28ms/step
# 54.07% 확률로 부정 리뷰입니다.
# 841 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.75% 확률로 부정 리뷰입니다.
# 842 번째
# 1/1 [==============================] - 0s 24ms/step
# 54.70% 확률로 긍정 리뷰입니다.
# 843 번째
# 1/1 [==============================] - 0s 23ms/step
# 50.04% 확률로 긍정 리뷰입니다.
# 844 번째
# 1/1 [==============================] - 0s 21ms/step
# 58.59% 확률로 긍정 리뷰입니다.
# 845 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.17% 확률로 부정 리뷰입니다.
# 846 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.16% 확률로 부정 리뷰입니다.
# 847 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.41% 확률로 긍정 리뷰입니다.
# 848 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.62% 확률로 부정 리뷰입니다.
# 849 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.42% 확률로 긍정 리뷰입니다.
# 850 번째
# 1/1 [==============================] - 0s 24ms/step
# 50.46% 확률로 긍정 리뷰입니다.
# 851 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.29% 확률로 긍정 리뷰입니다.
# 852 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.79% 확률로 긍정 리뷰입니다.
# 853 번째
# 1/1 [==============================] - 0s 24ms/step
# 56.37% 확률로 부정 리뷰입니다.
# 854 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.64% 확률로 부정 리뷰입니다.
# 855 번째
# 1/1 [==============================] - 0s 23ms/step
# 53.77% 확률로 긍정 리뷰입니다.
# 856 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.11% 확률로 부정 리뷰입니다.
# 857 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.21% 확률로 긍정 리뷰입니다.
# 858 번째
# 1/1 [==============================] - 0s 21ms/step
# 56.00% 확률로 부정 리뷰입니다.
# 859 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.13% 확률로 긍정 리뷰입니다.
# 860 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.69% 확률로 긍정 리뷰입니다.
# 861 번째
# 1/1 [==============================] - 0s 20ms/step
# 57.22% 확률로 긍정 리뷰입니다.
# 862 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.59% 확률로 긍정 리뷰입니다.
# 863 번째
# 1/1 [==============================] - 0s 21ms/step
# 59.18% 확률로 부정 리뷰입니다.
# 864 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.45% 확률로 부정 리뷰입니다.
# 865 번째
# 1/1 [==============================] - 0s 23ms/step
# 52.11% 확률로 부정 리뷰입니다.
# 866 번째
# 1/1 [==============================] - 0s 18ms/step
# 50.44% 확률로 긍정 리뷰입니다.
# 867 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.63% 확률로 긍정 리뷰입니다.
# 868 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.07% 확률로 부정 리뷰입니다.
# 869 번째
# 1/1 [==============================] - 0s 22ms/step
# 51.74% 확률로 부정 리뷰입니다.
# 870 번째
# 1/1 [==============================] - 0s 22ms/step
# 50.69% 확률로 긍정 리뷰입니다.
# 871 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.26% 확률로 긍정 리뷰입니다.
# 872 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.46% 확률로 부정 리뷰입니다.
# 873 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.69% 확률로 긍정 리뷰입니다.
# 874 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.28% 확률로 부정 리뷰입니다.
# 875 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.10% 확률로 부정 리뷰입니다.
# 876 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.23% 확률로 부정 리뷰입니다.
# 877 번째
# 1/1 [==============================] - 0s 18ms/step
# 55.26% 확률로 긍정 리뷰입니다.
# 878 번째
# 1/1 [==============================] - 0s 21ms/step
# 51.85% 확률로 긍정 리뷰입니다.
# 879 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.94% 확률로 긍정 리뷰입니다.
# 880 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.49% 확률로 부정 리뷰입니다.
# 881 번째
# 1/1 [==============================] - 0s 24ms/step
# 52.71% 확률로 부정 리뷰입니다.
# 882 번째
# 1/1 [==============================] - 0s 25ms/step
# 55.38% 확률로 긍정 리뷰입니다.
# 883 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.48% 확률로 부정 리뷰입니다.
# 884 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.99% 확률로 부정 리뷰입니다.
# 885 번째
# 1/1 [==============================] - 0s 20ms/step
# 53.41% 확률로 부정 리뷰입니다.
# 886 번째
# 1/1 [==============================] - 0s 24ms/step
# 52.60% 확률로 긍정 리뷰입니다.
# 887 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.18% 확률로 부정 리뷰입니다.
# 888 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.72% 확률로 부정 리뷰입니다.
# 889 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.57% 확률로 부정 리뷰입니다.
# 890 번째
# 1/1 [==============================] - 0s 20ms/step
# 50.52% 확률로 긍정 리뷰입니다.
# 891 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.96% 확률로 부정 리뷰입니다.
# 892 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.75% 확률로 긍정 리뷰입니다.
# 893 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.67% 확률로 부정 리뷰입니다.
# 894 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.74% 확률로 긍정 리뷰입니다.
# 895 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.54% 확률로 긍정 리뷰입니다.
# 896 번째
# 1/1 [==============================] - 0s 19ms/step
# 50.37% 확률로 부정 리뷰입니다.
# 897 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.79% 확률로 부정 리뷰입니다.
# 898 번째
# 1/1 [==============================] - 0s 19ms/step
# 51.62% 확률로 긍정 리뷰입니다.
# 899 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.76% 확률로 부정 리뷰입니다.
# 900 번째
# 1/1 [==============================] - 0s 21ms/step
# 53.29% 확률로 긍정 리뷰입니다.
# 901 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.27% 확률로 긍정 리뷰입니다.
# 902 번째
# 1/1 [==============================] - 0s 21ms/step
# 52.28% 확률로 긍정 리뷰입니다.
# 903 번째
# 1/1 [==============================] - 0s 25ms/step
# 50.06% 확률로 긍정 리뷰입니다.
# 904 번째
# 1/1 [==============================] - 0s 18ms/step
# 54.13% 확률로 긍정 리뷰입니다.
# 905 번째
# 1/1 [==============================] - 0s 18ms/step
# 51.16% 확률로 부정 리뷰입니다.
# 906 번째
# 1/1 [==============================] - 0s 20ms/step
# 51.21% 확률로 긍정 리뷰입니다.
# 907 번째
# 1/1 [==============================] - 0s 21ms/step
# 50.32% 확률로 긍정 리뷰입니다.
# 908 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.13% 확률로 부정 리뷰입니다.
# 909 번째
# 1/1 [==============================] - 0s 20ms/step
# 54.44% 확률로 부정 리뷰입니다.
# 910 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.85% 확률로 부정 리뷰입니다.
# 911 번째
# 1/1 [==============================] - 0s 19ms/step
# 52.70% 확률로 부정 리뷰입니다.
# 912 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.63% 확률로 긍정 리뷰입니다.
# 913 번째
# 1/1 [==============================] - 0s 19ms/step
# 53.05% 확률로 긍정 리뷰입니다.
# 914 번째
# 1/1 [==============================] - 0s 30ms/step
# 51.70% 확률로 부정 리뷰입니다.
# 915 번째
# 1/1 [==============================] - 0s 19ms/step
# 56.39% 확률로 부정 리뷰입니다.
# 916 번째
# 1/1 [==============================] - 0s 19ms/step
# 55.48% 확률로 부정 리뷰입니다.
# 917 번째
# 1/1 [==============================] - 0s 21ms/step
# 54.40% 확률로 부정 리뷰입니다.

# %%
df['sentiment'] = sent
df.to_csv('./crawling_data/apple_thinq_sentiment.csv', encoding='utf-8 sig')

# %%
df
# Out:
#        userName                       date  rating  like  \
# 0         강남오렌지  2022-07-24 20:24:44-07:00       1     0
# 1         우주괴에물  2022-07-24 08:08:11-07:00       1     0
# 2          ㅇ헣ㄹㅇ  2022-07-24 05:57:38-07:00       5     0
# 3           까암씨  2022-07-23 22:59:15-07:00       5     0
# 4       라이프이즈구웃  2022-07-23 07:35:17-07:00       4     0
# ..          ...                        ...     ...   ...
# 913  ㅎㅎㅋㅋㅎㅎㄹㅋㄱㅁ  2019-06-22 04:15:25-07:00       3     0
# 914        샤레레마  2018-04-26 16:36:23-07:00       5     0
# 915       Myoyu  2021-08-28 16:29:22-07:00       2     0
# 916        초등학생  2021-08-22 00:19:29-07:00       3     0
# 917          캐쓸  2021-08-13 04:45:44-07:00       5     0
#
#                      title                                             review  \
# 0              스마트케어 온도 설정   기준 온도 직접 설정 27도로 설정해놨는데, 자꾸 희망온도가 28도로 올라감...하..
# 1                 TV 연결 안됨  유튜브나 넷플릭스에서는 같은 네트워크일 때 연결하겠습니까 잘 뜨는데 씽큐에서 제품연...
# 2                        굿                                          엘지 iot 시작
# 3    건조기 등록이 너무 어려워 별 4 개요                      건조기 등록이 너무 잘안되용. 그래서 4 개 입니다.
# 4                 백색가전은 엘지                               앱으로 가전 제품 관리하기가 용이해요
# ..                     ...                                                ...
# 913                 우와 했는데  오늘 에어컨 설치하고 어플받고 제품등록 싹하고 기존에 있던 공기청정기 등록 다하고 ...
# 914            관리를 안하는건가요?  원격제품은 팔아놓으시고 서비스관리는 안하시는 건가요? 저번에도 그랬는데 어제부터 서...
# 915     업데이트후 제습기 예약 동작 오류  매일, 일정시간에 켜고 일정시간후 끄기 예약 기능 잘 사용하고 있었는데 업데이트후 ...
# 916  에어컨 네트워크 보안 WPA3 지원요청  에어컨 네트워크 보안 WAP3 지원 요청합니다.\n\n현재는 지원을 안해서 WPA/...
# 917    에어컨 펌웨어했는데 달라진게 없어요              동결건조 같은 관리 기능이 추가된 것 같은데 아무런 변화가 없습니다
#
#                                                content  \
# 0    스마트케어 온도 설정 기준 온도 직접 설정 27도로 설정해놨는데, 자꾸 희망온도가 ...
# 1    TV 연결 안됨 유튜브나 넷플릭스에서는 같은 네트워크일 때 연결하겠습니까 잘 뜨는데...
# 2                                          굿 엘지 iot 시작
# 3    건조기 등록이 너무 어려워 별 4 개요 건조기 등록이 너무 잘안되용. 그래서 4 개...
# 4                        백색가전은 엘지 앱으로 가전 제품 관리하기가 용이해요
# ..                                                 ...
# 913  우와 했는데 오늘 에어컨 설치하고 어플받고 제품등록 싹하고 기존에 있던 공기청정기 ...
# 914  관리를 안하는건가요? 원격제품은 팔아놓으시고 서비스관리는 안하시는 건가요? 저번에도...
# 915  업데이트후 제습기 예약 동작 오류 매일, 일정시간에 켜고 일정시간후 끄기 예약 기능...
# 916  에어컨 네트워크 보안 WPA3 지원요청 에어컨 네트워크 보안 WAP3 지원 요청합니...
# 917  에어컨 펌웨어했는데 달라진게 없어요 동결건조 같은 관리 기능이 추가된 것 같은데 아...
#
#                                              content_n  \
# 0    ['스마트', '케어', '온도', '설정', '기준', '온도', '직접', '설...
# 1    ['TV', '연결', '유튜브', '넷플릭스', '네트워크', '연결하다', '자...
# 2                             ['굿', '엘지', 'iot', '시작']
# 3    ['건조기', '등록', '너무', '어렵다', '별', '개요', '건조기', '...
# 4        ['백색', '가전', '엘지', '앱', '가전제품', '관리', '용이하다']
# ..                                                 ...
# 913  ['오늘', '에어컨', '설치', '어플', '받다', '제품', '등록', '싹...
# 914  ['관리', '건가', '원격', '제품', '파다', '서비스', '관리', '건...
# 915  ['업데이트', '제습기', '예약', '동작', '오류', '매일', '일정', ...
# 916  ['에어컨', '네트워크', '보안', 'WPA', '지원', '요청', '에어컨'...
# 917  ['에어컨', '펌웨어', '달라지다', '게', '동결', '건조', '관리', ...
#
#                                         cotent_n_spell  sentiment
# 0    ['스마트케어 온도 설정 기준 온도 직접 설정 도로 설정해놨는데', '자꾸 희망온도...   0.468290
# 1    ['TV 연결 안 됨 유튜브나 넷플릭스에서는 같은 네트워크일 때 연결하겠습니까', ...   0.516256
# 2                                      ['굿 엘지 iot 시작']   0.462415
# 3    ['건조기 등록이 너무 어려워 별 개요 건조기 등록이 너무 잘 안돼요', '그래서 ...   0.447790
# 4                     ['백색가전은 엘지 앱으로 가전제품 관리하기가 용이해요']   0.480265
# ..                                                 ...        ...
# 913  ['우와 했는데 오늘 에어컨 설치하고 어플 받고 제품 등록 싹하고 기존에 있던 공기...   0.530520
# 914  ['관리를 안 하는 건가요 원격 제품은 팔아놓으시고 서비스 관리는 안 하시는 건가요...   0.483015
# 915  ['업데이트 후 제습기 예약 동작 오류 매일 일정 시간에 켜고 일정 시간 후 끄기 ...   0.436137
# 916  ['에어컨 네트워크 보안 WPA 지원 요청 에어컨 네트워크 보안 WAP 지원 요청합...   0.445189
# 917  ['에어컨 펌웨어 했는데 달라진 게 없어요', '동결건조 같은 관리 기능이 추가된 ...   0.455984
#
# [918 rows x 10 columns]

# %%
df['content_n'][(df['sentiment']<0.50)].index
# Out:
# Int64Index([  0,   2,   3,   4,   5,   6,   7,  10,  11,  12,
#             ...
#             899, 905, 908, 909, 910, 911, 914, 915, 916, 917],
#            dtype='int64', length=602)

# %%
df.iloc[899]
# Out:
# userName                                               별 하나도 아깝다ㄷ ㄷ
# date                                      2019-06-27 20:27:01-07:00
# rating                                                            2
# like                                                              0
# title                                                 대체적으로 유용하긴 한데
# review            얼마전에 앱 점검을 하더니 알림이 안오기 시작하네요 전엔 앱을 켜지 않아도 세탁기나...
# content           대체적으로 유용하긴 한데 얼마전에 앱 점검을 하더니 알림이 안오기 시작하네요 전엔 ...
# content_n         ['체적', '유용하다', '전', '앱', '점검', '알림', '오기', '시작...
# cotent_n_spell    ['대체적으로 유용하긴 한데 얼마 전에 앱 점검을 하더니 알림이 안 오기 시작하네요...
# sentiment                                                  0.472369
# Name: 899, dtype: object
